# %% [markdown]
# 안녕하세요.<br><br>
# 수강생 여러분~! Chapter05 ~ 08 수업은 잘 들으셨나요?
#
# Chapter05 ~ 08의 수업 내용을 바탕으로 아래 문제를 풀어주시면 됩니다.
#
# <br>
#
#
# [**답변 입력 방법**]
#
# 문제 아래에 있는 코드 입력창에 정답코드를 작성하신 후  __▷ 버튼을 클릭해 코드를 실행__ 해보세요<br>

# %% [markdown]
# -----

# %% [markdown]
# __[문제0]__
# <br>
#
# ##### 이전 과제에서 "도전! 신비의 섬 탐험" 을 변수를 이용해서 다시 풀어보세요 !!!!!

# %% [markdown]
# __[문제1]__
#
# <br>
# 변수명 게임에 들어 있는 값 중 '홀'만 출력되도록 코드를 작성해 주세요
#
# game = "홀짝홀짝홀짝"
#
# 출력 예시 : "홀홀홀"

# %% [markdown]
# __Tips__
# - 문자열 슬라이싱을 이용해보세요 !

# %%
game = "홀짝홀짝홀짝"
print(game[::2])
# Out:
# 홀홀홀

# %% [markdown]
# ---

# %% [markdown]
# __[문제2]__
#
# <br>
#
# 변수명 전화번호에 들어 있는 번호를 모두 붙여서 출력되도록 코드를 작성해주세요.
#
# <br>
#
# phone = "010-1234-5678"
#
# 출력 예시 : "01012345678"

# %% [markdown]
# __Tips__
# - split() 함수는 문자열을 특정 구분자를 기준으로 나누어 리스트로 반환합니다.

# %%
phone = "010-1234-5768"
phone1 = phone.split("-")
print(phone1)
# Out:
# ['010', '1234', '5768']

# %% [markdown]
# ----

# %% [markdown]
# <br>
#
# __[문제3]__
#
# <br>
#
# 오즈 코딩 스쿨 백엔드 8기 과정에 참여한 수강생 중 5명의 수강생이 자율적으로 스터디 그룹을 결성했습니다.
#
# 스터디 그룹 내에는 한 주간 배운 내용으로 매주 쪽지 시험을 보는 룰이 있습니다.
#
# 이 쪽지 시험의 평균이 70점이 넘으면 주말 스터디는 없습니다.
#
# 주말 스터디의 여부를 True 또는 False로 출력해주세요.
#
# <br>
# A: 70, B: 75, C: 50, D: 80, E: 60
#
# <br>

# %%
print(f'A:{70 <= 70} B:{70 <= 75} C:{70 <= 50} D:{70 <= 80} E:{70 <= 60} 평균 이상 나와서 이번주 주말스터디 를 하지않겠습니다.👏👏👏👏👏👏')
# Out:
# A:True B:True C:False D:True E:False 평균 이상 나와서 이번주 주말스터디 를 하지않겠습니다.👏👏👏👏👏👏

# %% [markdown]
# __[문제4]__
#
# <br>
#
# 창의성, 시장성, 안정성, 수익성에 대한 각각의 평가 중 아래 기준에 부합하지 못하면 창업지원을 받을 수 없습니다.
#
# - 수익성 60점 이상
# - 창의성과 시장성 50점 이상
# - 시장성과 수익성을 더한 값의 절반이 안정성 보다 높아야 함
#
#
# 다음 점수가 입력되었을때 창업 지원이 가능한지 여부를 True 또는 False로 출력해주세요.
#
# ---
#
# 창의성 : 62
# 시장성 : 71
# 안정성 : 68
# 수익성 : 66
# <br>
#
# * 참고
# (creativity ,
# marketability ,
# stability ,
# profitability )

# %% [markdown]
# __Tips__
# * 비교 연산자와 논리 연산자의 결과를 고려해보아요

# %%
#비교연산자 / 논리연산자
#start-up support = profitability : 60 points or more , stability and marketability 50 points or more , marketabiliity and profitability half ofthe added value must be higher than stability
startupsupport = "creativity 62, marketability = 71, stability = 68, profitability = 66"
profitability = 66 >= 60
creativity = 62 >= 50 or 71 >= 50
stability = 71 + 66 / 2 >= 68  
print(f'{profitability} {creativity} {stability} / You can apply for start-up support.')
# Out:
# True True True / You can apply for start-up support.

# %% [markdown]
# ## 모험가들의 레벨업 도전
#
# ### [배경 이야기]
#
# 당신은 마법사, 전사, 도적, 힐러 네 명의 모험가를 이끄는 리더입니다.
#
# 각 캐릭터는 힘, 민첩, 지능, 체력이라는 능력치를 가지고 있습니다. 이 능력치들을 이용해 다양한 도전을 해결하고 사냥을 통해 경험치를 얻어 레벨업을 해야 합니다.
#
# <br>
#
# ### [동료 캐릭터와 능력치 정보]
#
# 마법사: 힘(10), 민첩(20), 지능(80), 체력(50)
#
# 전사: 힘(80), 민첩(30), 지능(20), 체력(100)
#
# 도적: 힘(40), 민첩(80), 지능(30), 체력(60)
#
# 힐러: 힘(20), 민첩(40), 지능(70), 체력(70)
#
# <br>
#
# * 변수명을 영어로 변경해서 풀어보세요 !

# %% [markdown]
# <br>
#
# __[문제 1: 첫 번째 사냥]__
#
# 마법사는 몬스터를 사냥하기 위해 마법을 사용합니다.
#
# 마법을 사용하려면 지능이 50 이상이어야 합니다.
#
# 마법사의 지능이 50 이상인지 확인하세요.

# %%
wizard_ability ="power 10, agility 20 , interlligence 80 , stamina 50"
monster_interlligence = 50 
wizard_interlligence = 80
monster_hunting = wizard_interlligence != monster_interlligence 

print(f'interlligence Check: {monster_hunting} / [Wizards are more intelligent!]' )
# Out:
# interlligence Check: True / [Wizards are more intelligent!]

# %% [markdown]
# <br>
#
# __[문제 2: 두 번째 사냥]__
#
# 전사는 강력한 공격을 하기 위해 자신의 힘을 사용합니다.
#
# 전사의 힘이 60 이상이고 체력이 80 이상인지 확인하세요.

# %%
warrior_ability ="power 80, agility 30 , interlligence 20 , stamina 100"
warrior_power = 80
warrior_stamina = 100
physical_ability_test = 100
warrior_power_test1= physical_ability_test >= warrior_power
warrior_stamina_test2 = physical_ability_test >= warrior_stamina

print(f'power check: {warrior_power_test1} / stamina check: {warrior_stamina_test2} / [Your physical ability is very high!]')
# Out:
# power check: True / stamina check: True / [Your physical ability is very high!]

# %% [markdown]
# <br>
#
# __[문제 3: 세 번째 사냥]__
#
# 도적은 민첩함을 이용해 몬스터를 회피하고 공격합니다.
#
# 도적의 민첩이 70 이상이거나 힘이 50 이상인지 확인하세요.

# %%
plunderer_ability ="power 40, agility 80 , interlligence 30 , stamina 60"
plunderer_agility = 80
plunderer_power = 40
agility_check = 100
plunderer_agility_ppwer_check =  agility_check >= plunderer_agility and agility_check == plunderer_power

print(f'Check: {plunderer_agility_ppwer_check} / [Agility is high, but power is low. Increase power!]')
# Out:
# Check: False / [Agility is high, but power is low. Increase power!]

# %% [markdown]
# <br>
#
# __[문제 4: 네 번째 사냥]__
#
# 힐러는 파티의 체력을 회복시키기 위해 마법을 사용합니다.
#
# 힐러의 지능이 60 이상이고, 체력이 50 이상인지 확인하세요.

# %%
healer_ability ="power 20, agility 40 , interlligence 70 , stamina 70"
healer_agility = 70
healer_stamina = 70
agility_check = 100
Healer_intelligence_and_stamina_check = agility_check >= healer_agility or agility_check >= healer_stamina

print(f'Check: {Healer_intelligence_and_stamina_check} / [Healers can heal party members. Recover quickly and defeat the villains!]')
# Out:
# Check: True / [Healers can heal party members. Recover quickly and defeat the villains!]

# %% [markdown]
# <br>
#
# __[문제 5: 레벨업]__
#
# 모든 캐릭터가 사냥을 성공적으로 마쳤습니다. 이제 경험치를 얻어 레벨업을 해야 합니다.
#
#
# 각 캐릭터의 경험치가 100 이상인지 print()를 이용해 확인해주세요.
#
# <br>
#
# 경험치는 아래와 같습니다.
#
# 마법사: 120
#
# 전사: 150
#
# 도적: 110
#
# 힐러: 90

# %%
Exp_wizard = 120
Exp_warrior = 150
Exp_plunderer = 110
Exp_Healer = 90 


print(f'EXP level of 100 or more: wizard: {Exp_wizard >= 100} / warrior: {Exp_warrior >= 100} / plunderer: { Exp_plunderer >= 100} / Healer: {Exp_Healer >= 100} / [Everyone soon You can level up!]')
# Out:
# EXP level of 100 or more: wizard: True / warrior: True / plunderer: True / Healer: False / [Everyone soon You can level up!]
